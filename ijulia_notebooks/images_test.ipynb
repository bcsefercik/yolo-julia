# %%
import Pkg
Pkg.activate(".")
import Images

import ImageDraw

include("coco2014.jl")
labels = JSON.parsefile(
            "val_labels.json";
            dicttype=Dict,
            inttype=Integer,
            use_mmap=true
        );

include("utils/img.jl")
# Out:
#  Activating environment at `~/Desktop/MSc/repos/yolo-julia/Project.toml`
# draw_labels (generic function with 1 method)

# %%
img = Images.load("dataset/images/overfit/COCO_val2014_000000001103.jpg");
size(img)
# Out:
# (444, 640)

# %%
img, label = get_image_and_labels("COCO_val2014_000000001268", labels, "dataset/images/overfit/"; img_size=(444, 640))
draw_labels(img, label)
# Out:
# 416×416 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.553,0.506,0.486)  …  RGB{N0f8}(0.016,0.016,0.016)
#  RGB{N0f8}(0.31,0.282,0.251)      RGB{N0f8}(0.008,0.008,0.008)
#  RGB{N0f8}(0.29,0.275,0.259)      RGB{N0f8}(0.016,0.016,0.016)
#  RGB{N0f8}(0.063,0.051,0.055)     RGB{N0f8}(0.024,0.024,0.031)
#  RGB{N0f8}(0.039,0.027,0.027)     RGB{N0f8}(0.02,0.02,0.027)
#  RGB{N0f8}(0.051,0.031,0.027)  …  RGB{N0f8}(0.008,0.008,0.008)
#  RGB{N0f8}(0.192,0.149,0.133)     RGB{N0f8}(0.008,0.008,0.008)
#  RGB{N0f8}(0.424,0.361,0.333)     RGB{N0f8}(0.012,0.008,0.012)
#  RGB{N0f8}(0.494,0.443,0.42)      RGB{N0f8}(0.016,0.012,0.02)
#  RGB{N0f8}(0.478,0.447,0.427)     RGB{N0f8}(0.02,0.016,0.031)
#  RGB{N0f8}(0.329,0.314,0.294)  …  RGB{N0f8}(0.035,0.031,0.047)
#  RGB{N0f8}(0.251,0.235,0.22)      RGB{N0f8}(0.031,0.027,0.039)
#  RGB{N0f8}(0.2,0.18,0.18)         RGB{N0f8}(0.012,0.016,0.016)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.086,0.082,0.106)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.086,0.078,0.098)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.086,0.078,0.098)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.086,0.078,0.098)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.098,0.094,0.114)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.09,0.09,0.106)       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.102,0.102,0.114)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.149,0.149,0.157)     RGB{N0f8}(0.106,0.173,0.227)
#  RGB{N0f8}(0.153,0.153,0.161)     RGB{N0f8}(0.09,0.157,0.212)
#  RGB{N0f8}(0.133,0.129,0.137)     RGB{N0f8}(0.078,0.145,0.192)
#  RGB{N0f8}(0.169,0.161,0.173)     RGB{N0f8}(0.075,0.145,0.176)
#  RGB{N0f8}(0.169,0.161,0.173)  …  RGB{N0f8}(0.098,0.157,0.176)

# %%
x1 = 10
y1 = 100
x2 = 20
y2 = 300

# function get_bbox(x1, y1,)

img_box = ImageDraw.draw(img_resized, ImageDraw.Polygon([(x1, y1), (x2,y1), (x2, y2), (x1, y2)]))
# Out:
# 416×416 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.643,0.643,0.643)  …  RGB{N0f8}(0.757,0.757,0.757)
#  RGB{N0f8}(0.627,0.627,0.627)     RGB{N0f8}(0.765,0.765,0.765)
#  RGB{N0f8}(0.537,0.537,0.537)     RGB{N0f8}(0.78,0.78,0.78)
#  RGB{N0f8}(0.549,0.549,0.549)     RGB{N0f8}(0.749,0.749,0.749)
#  RGB{N0f8}(0.71,0.71,0.71)        RGB{N0f8}(0.737,0.737,0.737)
#  RGB{N0f8}(0.737,0.737,0.737)  …  RGB{N0f8}(0.698,0.698,0.698)
#  RGB{N0f8}(0.757,0.757,0.757)     RGB{N0f8}(0.729,0.729,0.729)
#  RGB{N0f8}(0.659,0.659,0.659)     RGB{N0f8}(0.706,0.706,0.706)
#  RGB{N0f8}(0.631,0.631,0.631)     RGB{N0f8}(0.694,0.694,0.694)
#  RGB{N0f8}(0.694,0.694,0.694)     RGB{N0f8}(0.718,0.718,0.718)
#  RGB{N0f8}(0.706,0.706,0.706)  …  RGB{N0f8}(0.741,0.741,0.741)
#  RGB{N0f8}(0.71,0.71,0.71)        RGB{N0f8}(0.706,0.706,0.706)
#  RGB{N0f8}(0.729,0.729,0.729)     RGB{N0f8}(0.678,0.678,0.678)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.396,0.396,0.396)     RGB{N0f8}(0.494,0.494,0.494)
#  RGB{N0f8}(0.416,0.416,0.416)  …  RGB{N0f8}(0.506,0.506,0.506)
#  RGB{N0f8}(0.435,0.435,0.435)     RGB{N0f8}(0.525,0.525,0.525)
#  RGB{N0f8}(0.424,0.424,0.424)     RGB{N0f8}(0.537,0.537,0.537)
#  RGB{N0f8}(0.42,0.42,0.42)        RGB{N0f8}(0.545,0.545,0.545)
#  RGB{N0f8}(0.42,0.42,0.42)        RGB{N0f8}(0.541,0.541,0.541)
#  RGB{N0f8}(0.42,0.42,0.42)     …  RGB{N0f8}(0.529,0.529,0.529)
#  RGB{N0f8}(0.416,0.416,0.416)     RGB{N0f8}(0.525,0.525,0.525)
#  RGB{N0f8}(0.424,0.424,0.424)     RGB{N0f8}(0.533,0.533,0.533)
#  RGB{N0f8}(0.424,0.424,0.424)     RGB{N0f8}(0.525,0.525,0.525)
#  RGB{N0f8}(0.392,0.392,0.392)     RGB{N0f8}(0.529,0.529,0.529)
#  RGB{N0f8}(0.4,0.4,0.4)        …  RGB{N0f8}(0.522,0.522,0.522)
